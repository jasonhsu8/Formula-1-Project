# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset_folder_path = 'Dataset/'
def read_data(x):
    df = pd.read_csv(f'{dataset_folder_path}{x}')
    return df

# %%
circuits = read_data("circuits.csv")
drivers = read_data("drivers.csv")
laptimes = read_data("lap_times.csv")
races= read_data("races.csv")
results = read_data("results.csv")
status = read_data("status.csv")

# %%
top_100 = read_data("top_100_races_f1.csv")
top_100
# Out:
#     Ranking  raceId  circuitId                     name  rating  year
# 0         1     879         18     Brazilian Grand Prix    9.45  2012
# 1         2    1020         10        German Grand Prix    9.44  2019
# 2         3     843         17       Chinese Grand Prix    9.24  2011
# 3         4     906          7      Canadian Grand Prix    9.19  2014
# 4         5     910         11     Hungarian Grand Prix    9.14  2014
# ..      ...     ...        ...                      ...     ...   ...
# 95       96     855         22      Japanese Grand Prix    7.57  2011
# 96       97     975          7      Canadian Grand Prix    7.55  2017
# 97       98     353         35  South Korean Grand Prix    7.54  2010
# 98       99     970         17       Chinese Grand Prix    7.53  2017
# 99      100     853         14       Italian Grand Prix    7.49  2011
#
# [100 rows x 6 columns]

# %%
top_100['name'].unique()
# Out:
# array(['Brazilian Grand Prix', 'German Grand Prix', 'Chinese Grand Prix',
#        'Canadian Grand Prix', 'Hungarian Grand Prix',
#        'United States Grand Prix', 'Bahrain Grand Prix',
#        'Russian Grand Prix', 'Turkish Grand Prix', 'British Grand Prix',
#        'Austrian Grand Prix', 'Abu Dhabi Grand Prix', 'Sakhir Grand Prix',
#        'Azerbaijan Grand Prix', 'European Grand Prix',
#        'Spanish Grand Prix', 'Australian Grand Prix',
#        'Malaysian Grand Prix', 'Italian Grand Prix', 'Belgian Grand Prix',
#        'Sao Paulo Grand Prix', 'French Grand Prix', 'Monaco Grand Prix',
#        'Emilia-Romagna Grand Prix', 'Saudi Arabian Grand Prix',
#        'Japanese Grand Prix', 'South Korean Grand Prix'], dtype=object)

# %%
top_100['year'].unique()
# Out:
# array([2012, 2019, 2011, 2014, 2015, 2021, 2020, 2022, 2017, 2018, 2008,
#        2016, 2010, 2009, 2013], dtype=int64)

# %%
type_top_100 = {
    "Ranking": str,
    "raceId": int,
    "circuitId": int,
    "name": str,
    "rating": float,
    "year": int
}
top_100 = top_100.astype(type_top_100, errors="ignore")
top_100.dropna(how="any", inplace=True)

# %%
year_colors={
    2008: 'rebeccapurple',
    2009: 'blue',
    2010: 'lime',
    2011: 'orange',
    2012: 'skyblue',
    2013: 'red',
    2014: 'turquoise',
    2015: 'yellow',
    2016: 'darkgreen',
    2017: 'khaki',
    2018: 'hotpink',
    2019: 'aqua',
    2020: 'crimson',
    2021: 'darkolivegreen',
    2022: 'sandybrown'
}

# %%
#Hypothesis 1, do certain circuits have better average race rating?

#Scatter plot rating vs year
plt.figure(figsize=(12,6))
plt.scatter(x=top_100['year'], y=top_100['rating'], color=[year_colors[year] for year in top_100["year"]])
plt.title("Scatter Plot Showing Rating Against Year")
plt.xlabel("Year")
plt.ylabel("Race Rating")
plt.xticks(top_100['year'].unique())
plt.show()

# %%
# Mean of Race Rating Per Year

top_100_mean = top_100.groupby(by="year", as_index=False).aggregate(
        {
            "rating": 'mean'
        }
    ).rename(({"rating": "Average Race Rating"}), axis = 1)
top_100_mean
# Out:
#     year  Average Race Rating
# 0   2008             8.058571
# 1   2009             8.033333
# 2   2010             8.255000
# 3   2011             8.136000
# 4   2012             8.472000
# 5   2013             7.712500
# 6   2014             8.483333
# 7   2015             8.632500
# 8   2016             7.963750
# 9   2017             7.913333
# 10  2018             8.404444
# 11  2019             8.615714
# 12  2020             8.632500
# 13  2021             8.338889
# 14  2022             8.065714

# %%
#Scatter plot Mean Race Rating vs year

plt.figure(figsize=(12,6))
bars = plt.bar(x=top_100_mean['year'], height=top_100_mean['Average Race Rating'], color=[year_colors[year] for year in top_100_mean["year"]])
plt.title("Bar Graph Showing Average Race Rating Against Year")
plt.xlabel("Year")
plt.ylabel("Average Race Rating")
plt.xticks(top_100_mean['year'].unique())

for bar, height in zip(bars, top_100_mean["Average Race Rating"]):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(round(height, 2)),
             ha='center', va='bottom', fontsize=10, color='black')
    
plt.show()

# %%
top_100_mean.sort_values(by="Average Race Rating", ascending=True)
top_100_mean_orderby_race_rating = top_100_mean
top_100_mean_orderby_race_rating
# Out:
#     year  Average Race Rating
# 0   2008             8.058571
# 1   2009             8.033333
# 2   2010             8.255000
# 3   2011             8.136000
# 4   2012             8.472000
# 5   2013             7.712500
# 6   2014             8.483333
# 7   2015             8.632500
# 8   2016             7.963750
# 9   2017             7.913333
# 10  2018             8.404444
# 11  2019             8.615714
# 12  2020             8.632500
# 13  2021             8.338889
# 14  2022             8.065714

# %%
#Boxplot for race rating
plt.figure(figsize=(12,8))
sns.boxplot(x='year', y='rating', data=top_100, hue='year', palette=year_colors)
plt.title("Boxplot of Race Rating Distribution by Year")
plt.xlabel("Year")
plt.ylabel("Race Rating")
plt.legend(title="Year", bbox_to_anchor=(1.01, 1), loc='upper left')
plt.show()

# %%
#Number of races per year
race_counts = top_100.groupby('year')['name'].count()

plt.figure(figsize=(12,6))
plt.bar(x=race_counts.index, height=race_counts.values, color=[year_colors[year] for year in race_counts.index])
plt.title("Top 100 Races from 2008-2022 per year")
plt.xlabel("Year")
plt.ylabel("Number of Races")
plt.xticks(top_100['year'].unique())
plt.show()

# %%
race_counts
# Out:
# year
# 2008     7
# 2009     3
# 2010     6
# 2011    10
# 2012    10
# 2013     4
# 2014     6
# 2015     4
# 2016     8
# 2017     6
# 2018     9
# 2019     7
# 2020     4
# 2021     9
# 2022     7
# Name: name, dtype: int64

# %%
top_100_circuits = pd.merge(top_100, circuits, on="circuitId", how="left")
top_100_circuits = top_100_circuits.drop(['lat', 'lng', 'alt', 'name_x'], axis=1)
top_100_circuits = top_100_circuits.rename(columns={'name_y': 'name'})
top_100_circuits
# Out:
#    Ranking  raceId  circuitId  rating  year      circuitRef  \
# 0        1     879         18    9.45  2012      interlagos
# 1        2    1020         10    9.44  2019  hockenheimring
# 2        3     843         17    9.24  2011        shanghai
# 3        4     906          7    9.19  2014      villeneuve
# 4        5     910         11    9.14  2014     hungaroring
# ..     ...     ...        ...     ...   ...             ...
# 95      96     855         22    7.57  2011          suzuka
# 96      97     975          7    7.55  2017      villeneuve
# 97      98     353         35    7.54  2010         yeongam
# 98      99     970         17    7.53  2017        shanghai
# 99     100     853         14    7.49  2011           monza
#
#                               name        location  country
# 0       Autódromo José Carlos Pace       São Paulo   Brazil
# 1                   Hockenheimring      Hockenheim  Germany
# 2   Shanghai International Circuit        Shanghai    China
# ...

# %%
top_100_circuits
# Out:
#    Ranking  raceId  circuitId  rating  year      circuitRef  \
# 0        1     879         18    9.45  2012      interlagos
# 1        2    1020         10    9.44  2019  hockenheimring
# 2        3     843         17    9.24  2011        shanghai
# 3        4     906          7    9.19  2014      villeneuve
# 4        5     910         11    9.14  2014     hungaroring
# ..     ...     ...        ...     ...   ...             ...
# 95      96     855         22    7.57  2011          suzuka
# 96      97     975          7    7.55  2017      villeneuve
# 97      98     353         35    7.54  2010         yeongam
# 98      99     970         17    7.53  2017        shanghai
# 99     100     853         14    7.49  2011           monza
#
#                               name        location  country
# 0       Autódromo José Carlos Pace       São Paulo   Brazil
# 1                   Hockenheimring      Hockenheim  Germany
# 2   Shanghai International Circuit        Shanghai    China
# ...

# %%
top_100_circuits = top_100_circuits.rename(
    columns={
        'name': 'Circuit Name',
        'rating': 'Race Rating',
        'year': 'Year',
        'location': 'Location',
        'country': 'Country'
            })
top_100_circuits.sort_values(by="Race Rating", ascending=False, inplace=True)
top_100_circuits
# Out:
#    Ranking  raceId  circuitId  Race Rating  Year      circuitRef  \
# 0        1     879         18         9.45  2012      interlagos
# 1        2    1020         10         9.44  2019  hockenheimring
# 2        3     843         17         9.24  2011        shanghai
# 3        4     906          7         9.19  2014      villeneuve
# 4        5     910         11         9.14  2014     hungaroring
# ..     ...     ...        ...          ...   ...             ...
# 95      96     855         22         7.57  2011          suzuka
# 96      97     975          7         7.55  2017      villeneuve
# 97      98     353         35         7.54  2010         yeongam
# 98      99     970         17         7.53  2017        shanghai
# 99     100     853         14         7.49  2011           monza
#
#                       Circuit Name        Location  Country
# 0       Autódromo José Carlos Pace       São Paulo   Brazil
# 1                   Hockenheimring      Hockenheim  Germany
# ...

# %%
#See if circuit matters in terms of rating
top_100_circuits['NameOfCircuit'] = top_100_circuits.loc[:, 'Circuit Name']
top_100_circuits = top_100_circuits.groupby(by=["NameOfCircuit", "Location", "Country"], as_index=False).aggregate(
    {
        "Circuit Name": 'count',
        "Race Rating": 'mean' 
    }
).rename(({"Circuit Name": "Circuit Count"}), axis = 1)

top_100_circuits.sort_values(by="Race Rating", ascending=False, inplace=True)
top_100_circuits
# Out:
#                      NameOfCircuit        Location       Country  \
# 22                  Sochi Autodrom           Sochi        Russia
# 24         Valencia Street Circuit        Valencia         Spain
# 3       Autódromo José Carlos Pace       São Paulo        Brazil
# 14                   Istanbul Park        Istanbul        Turkey
# 12                  Hockenheimring      Hockenheim       Germany
# 6        Circuit Gilles Villeneuve        Montreal        Canada
# 4    Bahrain International Circuit          Sakhir       Bahrain
# 13                     Hungaroring        Budapest       Hungary
# 5                Baku City Circuit            Baku    Azerbaijan
# 20  Shanghai International Circuit        Shanghai         China
# 11         Circuit of the Americas          Austin           USA
# 21             Silverstone Circuit     Silverstone            UK
# 8   Circuit de Barcelona-Catalunya        Montmeló         Spain
# ...

# %%
circuit_colors={
    "Autódromo José Carlos Pace": 'rebeccapurple',
    "Hockenheimring": 'blue',
    "Bahrain International Circuit": 'lime',
    "Hungaroring": 'orange',
    "Circuit of the Americas": 'skyblue',
    "Circuit de Barcelona-Catalunya": 'red',
    "Sepang International Circuit": 'turquoise',
    "Silverstone Circuit": 'yellow',
    "Nürburgring": 'darkgreen',
    "Shanghai International Circuit": 'khaki',
    "Istanbul Park": 'hotpink',
    "Autodromo Nazionale di Monza": 'aqua',
    "Circuit Gilles Villeneuve": 'crimson',
    "Red Bull Ring": 'darkolivegreen',
    "Korean International Circuit": 'sandybrown',
    "Albert Park Grand Prix Circuit": 'aquamarine',
    "Sochi Autodrom": 'plum',
    "Autodromo Enzo e Dino Ferrari": 'slategray',
    "Baku City Circuit": 'lightgreen',
    "Jeddah Corniche Circuit": 'brown',
    "Circuit de Spa-Francorchamps": 'cornflowerblue',
    "Yas Marina Circuit": 'dimgrey',
    "Valencia Street Circuit": 'wheat',
    "Circuit Park Zandvoort": 'azure',
    "Circuit de Monaco": 'indigo',
    "Suzuka Circuit": 'darkslategrey',
    "Losail International Circuit": 'lavender',
    "Marina Bay Street Circuit": 'salmon',
    "Autódromo Internacional do Algarve": 'linen',
    "Circuit Paul Ricard": 'lightgoldenrodyellow',
    "Miami International Autodrome": 'lawngreen',
    "Autódromo Hermanos Rodríguez": 'steelblue'
}

# %%
# Plot Bar Graph Count of Circuits in the top 100
top_100_circuits.sort_values(by="Circuit Count", ascending=False, inplace=True)
top_100_circuits_count = top_100_circuits

plt.figure(figsize=(20,8))
bars = plt.bar(x=top_100_circuits_count["NameOfCircuit"], height=top_100_circuits_count["Circuit Count"], color=[circuit_colors[CircuitName] for CircuitName in top_100_circuits_count["NameOfCircuit"]])
plt.title("Count of Circuits in the Top 100 Rated Races")
plt.xlabel("Circuit Name")
plt.ylabel("Count of Circuits")
plt.xticks(rotation=90)

for bar, height in zip(bars, top_100_circuits_count["Circuit Count"]):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(round(height, 2)),
             ha='center', va='bottom', fontsize=10, color='black')

plt.show()

# %%
race_ratings_2022_2021_2019 = read_data("All_Races_Ratings.csv")
race_ratings_2022_2021_2019
# Out:
#     raceId  circuitId                   name  rating  year
# 0     1094         32     Mexican Grand Prix    3.90  2022
# 1     1081         73  Azerbaijan Grand Prix    5.03  2022
# 2     1089         14     Italian Grand Prix    5.28  2022
# 3     1092         22    Japanese Grand Prix    5.44  2022
# 4     1078         79       Miami Grand Prix    5.63  2022
# ..     ...        ...                    ...     ...   ...
# 59    1011          3     Bahrain Grand Prix    8.50  2019
# 60    1019          9     British Grand Prix    8.60  2019
# 61    1029         18   Brazilian Grand Prix    8.80  2019
# 62    1018         70    Austrian Grand Prix    8.90  2019
# 63    1020         10       German Grad Prix    9.40  2019
#
# [64 rows x 5 columns]

# %%
#Race Ratings Data Frame
#Concat top 100 and race ratings from 2022, 2021, and 2019
#merge top 100 
race_ratings = pd.concat([top_100, race_ratings_2022_2021_2019])
race_ratings = race_ratings.drop_duplicates(subset='raceId')
race_ratings = race_ratings.drop(['Ranking'], axis=1)
race_ratings = pd.merge(race_ratings, circuits, on="circuitId", how="left")
race_ratings = race_ratings.drop(['lat', 'lng', 'alt'], axis=1)
race_ratings = race_ratings.rename(
    columns={
        'name_x': 'Grand Prix',
        'name_y': 'Circuit Name',
        'rating': 'Race Rating',
        'year': 'Year',
        'location': 'Location',
        'country': 'Country'
            })
race_ratings.sort_values(by="Race Rating", ascending=False, inplace=True)
race_ratings
# Out:
#      raceId  circuitId            Grand Prix  Race Rating  Year  \
# 0       879         18  Brazilian Grand Prix         9.45  2012
# 1      1020         10     German Grand Prix         9.44  2019
# 2       843         17    Chinese Grand Prix         9.24  2011
# 3       906          7   Canadian Grand Prix         9.19  2014
# 4       910         11  Hungarian Grand Prix         9.14  2014
# ..      ...        ...                   ...          ...   ...
# 129    1016          7   Canadian Grand Prix         4.40  2019
# 116    1056          6     Monaco Grand Prix         4.00  2021
# 100    1094         32    Mexican Grand Prix         3.90  2022
# 128    1017         34     French Grand Prix         3.50  2019
# 115    1063         13    Belgian Grand Prix         1.90  2021
#
#          circuitRef                    Circuit Name      Location  Country
# 0        interlagos      Autódromo José Carlos Pace     São Paulo   Brazil
# ...

# %%
race_ratings['Circuit Name'].unique()
# Out:
# array(['Autódromo José Carlos Pace', 'Hockenheimring',
#        'Shanghai International Circuit', 'Circuit Gilles Villeneuve',
#        'Hungaroring', 'Circuit of the Americas',
#        'Bahrain International Circuit', 'Sochi Autodrom', 'Istanbul Park',
#        'Silverstone Circuit', 'Red Bull Ring', 'Yas Marina Circuit',
#        'Baku City Circuit', 'Valencia Street Circuit',
#        'Circuit de Barcelona-Catalunya', 'Albert Park Grand Prix Circuit',
#        'Sepang International Circuit', 'Nürburgring',
#        'Autodromo Nazionale di Monza', 'Circuit de Spa-Francorchamps',
#        'Circuit Paul Ricard', 'Circuit de Monaco',
#        'Autodromo Enzo e Dino Ferrari', 'Jeddah Corniche Circuit',
#        'Suzuka Circuit', 'Korean International Circuit',
#        'Circuit Park Zandvoort', 'Autódromo Hermanos Rodríguez',
#        'Marina Bay Street Circuit', 'Losail International Circuit',
#        'Autódromo Internacional do Algarve',
# ...

# %%
#See if circuit matters in terms of rating
race_ratings['NameOfCircuit'] = race_ratings.loc[:, 'Circuit Name']
circuit_rating = race_ratings.groupby(by=["NameOfCircuit", "Location", "Country"], as_index=False).aggregate(
    {
        "Circuit Name": 'count',
        "Race Rating": 'mean' 
    }
).rename(({"Circuit Name": "Circuit Count"}), axis = 1)

circuit_rating.sort_values(by="Race Rating", ascending=False, inplace=True)
circuit_rating
# Out:
#                          NameOfCircuit        Location       Country  \
# 5           Autódromo José Carlos Pace       São Paulo        Brazil
# 15                      Hockenheimring      Hockenheim       Germany
# 6        Bahrain International Circuit          Sakhir       Bahrain
# 16                         Hungaroring        Budapest       Hungary
# 14             Circuit of the Americas          Austin           USA
# 11      Circuit de Barcelona-Catalunya        Montmeló         Spain
# 25        Sepang International Circuit    Kuala Lumpur      Malaysia
# 27                 Silverstone Circuit     Silverstone            UK
# 23                         Nürburgring         Nürburg       Germany
# 26      Shanghai International Circuit        Shanghai         China
# 17                       Istanbul Park        Istanbul        Turkey
# 2         Autodromo Nazionale di Monza           Monza         Italy
# 8            Circuit Gilles Villeneuve        Montreal        Canada
# ...

# %%
circuit_colors={
    "Autódromo José Carlos Pace": 'rebeccapurple',
    "Hockenheimring": 'blue',
    "Bahrain International Circuit": 'lime',
    "Hungaroring": 'orange',
    "Circuit of the Americas": 'skyblue',
    "Circuit de Barcelona-Catalunya": 'red',
    "Sepang International Circuit": 'turquoise',
    "Silverstone Circuit": 'yellow',
    "Nürburgring": 'darkgreen',
    "Shanghai International Circuit": 'khaki',
    "Istanbul Park": 'hotpink',
    "Autodromo Nazionale di Monza": 'aqua',
    "Circuit Gilles Villeneuve": 'crimson',
    "Red Bull Ring": 'darkolivegreen',
    "Korean International Circuit": 'sandybrown',
    "Albert Park Grand Prix Circuit": 'aquamarine',
    "Sochi Autodrom": 'plum',
    "Autodromo Enzo e Dino Ferrari": 'slategray',
    "Baku City Circuit": 'lightgreen',
    "Jeddah Corniche Circuit": 'brown',
    "Circuit de Spa-Francorchamps": 'cornflowerblue',
    "Yas Marina Circuit": 'dimgrey',
    "Valencia Street Circuit": 'wheat',
    "Circuit Park Zandvoort": 'azure',
    "Circuit de Monaco": 'indigo',
    "Suzuka Circuit": 'darkslategrey',
    "Losail International Circuit": 'lavender',
    "Marina Bay Street Circuit": 'salmon',
    "Autódromo Internacional do Algarve": 'linen',
    "Circuit Paul Ricard": 'lightgoldenrodyellow',
    "Miami International Autodrome": 'lawngreen',
    "Autódromo Hermanos Rodríguez": 'steelblue'
}

# %%
# Plot Bar Graph Count of Circuits in the dataset
circuit_rating.sort_values(by="Circuit Count", ascending=False, inplace=True)

circuit_rating_count = circuit_rating
plt.figure(figsize=(20,8))
bars = plt.bar(x=circuit_rating_count["NameOfCircuit"], height=circuit_rating_count["Circuit Count"], color=[circuit_colors[CircuitName] for CircuitName in circuit_rating_count["NameOfCircuit"]])
plt.title("Count of Circuits in the Full Dataset")
plt.xlabel("Circuit Name")
plt.ylabel("Count of Circuits")
plt.xticks(rotation=90)

for bar, height in zip(bars, circuit_rating_count["Circuit Count"]):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(round(height, 2)),
             ha='center', va='bottom', fontsize=10, color='black')

plt.show()

# %%
# Plot Bar Graph Circuits and their Average Race Rating
plt.figure(figsize=(20,8))
circuit_rating.sort_values(by="Race Rating", ascending=False, inplace=True)
circuit_rating_race_rating = circuit_rating
bars = plt.bar(x=circuit_rating_race_rating["NameOfCircuit"], height=circuit_rating_race_rating["Race Rating"], color=[circuit_colors[CircuitName] for CircuitName in circuit_rating_race_rating["NameOfCircuit"]])
plt.title("Circuits and Their Average Race Rating")
plt.xlabel("Circuit Name")
plt.ylabel("Average Race Rating")
plt.xticks(rotation=90)

for bar, height in zip(bars, circuit_rating_race_rating["Race Rating"]):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(round(height, 2)),
             ha='center', va='bottom', fontsize=10, color='black')

plt.show()

# %%
# Hypothesis 2
# Are DNFs a factor in making a good race?
# Let's start by looking at the Canadian Grand Prix 2014 one of the highest DNFs in F1
# raceId = 906

canadaian_grand_prix_stats = results[results['raceId'] == 906][['resultId', 'raceId', 'driverId', 'constructorId', 'grid', 'position', 'laps', 'statusId']]
canadaian_grand_prix_stats
# Out:
#        resultId  raceId  driverId  constructorId  grid position  laps  \
# 22259     22262     906       817              9     6        1    70
# 22260     22263     906         3            131     1        2    70
# 22261     22264     906        20              9     3        3    70
# 22262     22265     906        18              1     9        4    70
# 22263     22266     906       807             10    11        5    70
# 22264     22267     906         4              6     7        6    70
# 22265     22268     906       822              3     4        7    70
# 22266     22269     906       818              5     8        8    70
# 22267     22270     906       825              1    12        9    70
# 22268     22271     906         8              6    10       10    70
# 22269     22272     906       815             10    13       11    69
# 22270     22273     906        13              3     5       12    69
# ...

# %%
canadaian_grand_prix_stats = pd.merge(canadaian_grand_prix_stats, status, on="statusId", how="left")
canadaian_grand_prix_stats_dnf = canadaian_grand_prix_stats[canadaian_grand_prix_stats['position'] == "\\N"]
canadaian_grand_prix_stats_dnf
# Out of 22 drivers, 8 DNF the race
# Out:
#     resultId  raceId  driverId  constructorId  grid position  laps  statusId  \
# 14     22276     906       154            208    14       \N    59        65
# 15     22277     906       826              5    15       \N    47        79
# 16     22278     906         1            131     2       \N    46        23
# 17     22279     906       155            207    21       \N    23        22
# 18     22280     906       813            208    17       \N    21       131
# 19     22281     906       828            207    20       \N     7       101
# 20     22282     906       820            206    18       \N     0         4
# 21     22283     906       824            206    19       \N     0         4
#
#         status
# 14   Rear wing
# 15  Drivetrain
# 16      Brakes
# 17  Suspension
# 18  Power Unit
# 19       Turbo
# 20   Collision
# 21   Collision

# %%
status_finished_race = status[status['statusId'].isin(
    [1, 11, 12, 13, 14, 15, 16, 17, 18, 19, 45, 50, 128, 53, 55, 58, 88, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 122, 123, 124, 125, 127, 133, 134])]

status_finished_race
# Out:
#      statusId    status
# 0           1  Finished
# 10         11    +1 Lap
# 11         12   +2 Laps
# 12         13   +3 Laps
# 13         14   +4 Laps
# 14         15   +5 Laps
# 15         16   +6 Laps
# 16         17   +7 Laps
# 17         18   +8 Laps
# 18         19   +9 Laps
# 44         45  +11 Laps
# 49         50  +17 Laps
# 51        128  +42 Laps
# 52         53  +13 Laps
# 54         55  +12 Laps
# 57         58  +26 Laps
# 87         88  +10 Laps
# 110       111  +14 Laps
# 111       112  +15 Laps
# 112       113  +25 Laps
# 113       114  +18 Laps
# 114       115  +22 Laps
# 115       116  +16 Laps
# 116       117  +24 Laps
# 117       118  +29 Laps
# 118       119  +23 Laps
# 119       120  +21 Laps
# 121       122  +44 Laps
# 122       123  +30 Laps
# 123       124  +19 Laps
# 124       125  +46 Laps
# 126       127  +20 Laps
# 130       133  +49 Laps
# 131       134  +38 Laps

# %%
# Lets see this with all our races with a rating

race_ratings_drop = race_ratings.drop(['Country', 'Location', 'circuitRef', 'circuitId', 'Grand Prix'], axis=1)
races_drop = races.drop(['fp1_date', 'fp1_time', 'fp2_date', 'fp2_time', 'fp3_date', 'fp3_date', 'fp3_time', 'quali_date', 'quali_time', 'sprint_date', 'sprint_time', 'time', 'date'], axis=1)
race_stats_ratings = pd.merge(left=race_ratings_drop, right=races_drop, on='raceId', how='left')
race_stats_ratings = race_stats_ratings.dropna(axis=0)


race_stats_ratings
# Out:
#      raceId  Race Rating  Year                    Circuit Name  \
# 0       879         9.45  2012      Autódromo José Carlos Pace
# 1      1020         9.44  2019                  Hockenheimring
# 2       843         9.24  2011  Shanghai International Circuit
# 3       906         9.19  2014       Circuit Gilles Villeneuve
# 4       910         9.14  2014                     Hungaroring
# ..      ...          ...   ...                             ...
# 136    1016         4.40  2019       Circuit Gilles Villeneuve
# 137    1056         4.00  2021               Circuit de Monaco
# 138    1094         3.90  2022    Autódromo Hermanos Rodríguez
# 139    1017         3.50  2019             Circuit Paul Ricard
# 140    1063         1.90  2021    Circuit de Spa-Francorchamps
#
#                       NameOfCircuit  year  round  circuitId  \
# 0        Autódromo José Carlos Pace  2012     20         18
# 1                    Hockenheimring  2019     11         10
# ...

# %%
# Count number of DNFs function

def dnf_count(results_df, race_id_in_results):
    #counter for DNFs
    dnf_counter = 0
    #Array for each statusId that a driver finsihed the race in status.csv
    status_finished_race = [1, 11, 12, 13, 14, 15, 16, 17, 18, 19, 45, 50, 128, 53, 55, 58, 88, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 122, 123, 124, 125, 127, 133, 134]

    for i in results_df[results_df['raceId'] == race_id_in_results]['statusId']:
        if i not in status_finished_race:
            dnf_counter = dnf_counter + 1
        else:
            pass

    return dnf_counter

# %%
race_stats_ratings['DNF'] = race_stats_ratings.raceId.apply(lambda x: dnf_count(results, x))
race_stats_ratings.sort_values(by="DNF", ascending=False, inplace=True)
race_stats_ratings
# Out:
#      raceId  Race Rating  Year                    Circuit Name  \
# 93       18         7.61  2008  Albert Park Grand Prix Circuit
# 3       906         9.19  2014       Circuit Gilles Villeneuve
# 27      338         8.64  2010  Albert Park Grand Prix Circuit
# 90      860         7.66  2012  Albert Park Grand Prix Circuit
# 97      353         7.54  2010    Korean International Circuit
# ..      ...          ...   ...                             ...
# 12     1018         8.88  2019                   Red Bull Ring
# 107    1067         6.60  2021                   Istanbul Park
# 71      950         7.85  2016  Shanghai International Circuit
# 46     1059         8.23  2021             Circuit Paul Ricard
# 140    1063         1.90  2021    Circuit de Spa-Francorchamps
#
#                       NameOfCircuit  year  round  circuitId  \
# 93   Albert Park Grand Prix Circuit  2008      1          1
# 3         Circuit Gilles Villeneuve  2014      7          7
# ...

# %%
race_stats_ratings.sort_values(by="Race Rating", ascending=False, inplace=True)
race_stats_ratings
# Out:
#      raceId  Race Rating  Year                    Circuit Name  \
# 0       879         9.45  2012      Autódromo José Carlos Pace
# 1      1020         9.44  2019                  Hockenheimring
# 2       843         9.24  2011  Shanghai International Circuit
# 3       906         9.19  2014       Circuit Gilles Villeneuve
# 4       910         9.14  2014                     Hungaroring
# ..      ...          ...   ...                             ...
# 136    1016         4.40  2019       Circuit Gilles Villeneuve
# 137    1056         4.00  2021               Circuit de Monaco
# 138    1094         3.90  2022    Autódromo Hermanos Rodríguez
# 139    1017         3.50  2019             Circuit Paul Ricard
# 140    1063         1.90  2021    Circuit de Spa-Francorchamps
#
#                       NameOfCircuit  year  round  circuitId  \
# 0        Autódromo José Carlos Pace  2012     20         18
# 1                    Hockenheimring  2019     11         10
# ...

# %%
# Going to remove record 140 
# Anomolous reasult due to no DNFs as race did not occur
# Rating was affected because of lack of a race not due to DNFs

race_stats_ratings_no_spa_2021 = race_stats_ratings[:-1] # drop last row
race_stats_ratings_no_spa_2021
# Out:
#      raceId  Race Rating  Year                    Circuit Name  \
# 0       879         9.45  2012      Autódromo José Carlos Pace
# 1      1020         9.44  2019                  Hockenheimring
# 2       843         9.24  2011  Shanghai International Circuit
# 3       906         9.19  2014       Circuit Gilles Villeneuve
# 4       910         9.14  2014                     Hungaroring
# ..      ...          ...   ...                             ...
# 135    1014         4.60  2019         Valencia Street Circuit
# 136    1016         4.40  2019       Circuit Gilles Villeneuve
# 137    1056         4.00  2021               Circuit de Monaco
# 138    1094         3.90  2022    Autódromo Hermanos Rodríguez
# 139    1017         3.50  2019             Circuit Paul Ricard
#
#                       NameOfCircuit  year  round  circuitId  \
# 0        Autódromo José Carlos Pace  2012     20         18
# 1                    Hockenheimring  2019     11         10
# ...

# %%
def coef_linear_regression(x,y):
    n = np.size(x)
    x_mean = np.mean(x)
    y_mean = np.mean(y)
    ss_xy = np.sum(y*x) - n*y_mean*x_mean
    ss_xx = np.sum(x*x) - n*x_mean*x_mean

    gradient = ss_xy / ss_xx
    y_intercept = y_mean - gradient*x_mean

    return(y_intercept, gradient)

def correlation_coefficient(x,y):

    x_mean = np.mean(x)
    y_mean = np.mean(y)

    numerator = np.sum((x - x_mean) * (y - y_mean))
    x_denominator = np.sum((x - x_mean)**2)
    y_denominator = np.sum((y - y_mean)**2)
    denominator = np.sqrt(x_denominator * y_denominator)

    corr_coef = numerator / denominator

    return corr_coef


def plot_regression_line(x,y,b):
    plt.scatter(x, y, color='m', marker="o", s=30)

    y_pred = b[0]+b[1]*x
    plt.plot(x, y_pred, color="g")
    plt.show()

# %%
#Scatter plot DNFs against Race Rating
x = race_stats_ratings_no_spa_2021["Race Rating"]
y = race_stats_ratings_no_spa_2021["DNF"]
b = coef_linear_regression(x,y)

plt.figure(figsize=(14,8))
corr_coef_value_dnf = correlation_coefficient(x,y)
plt.title("Scatter Plot Showing DNFs against Race Rating\ny=mx+c where m=" 
          + str(round(b[1], 2)) + " and c=" + str(round(b[0], 2)) + 
          "\nPearson Correlation Coefficient: " + str(round(corr_coef_value_dnf , 2)))
plt.xlabel("Race Rating")
plt.ylabel("Number of DNFs (*Did Not Finish*)")
plot_regression_line(x,y,b)

# %%
brazil_race_ratings = race_stats_ratings[race_stats_ratings['Circuit Name'].str.contains("Autódromo José Carlos Pace", case=False, regex=True)]
brazil_race_ratings
# Out:
#     raceId  Race Rating  Year                Circuit Name  \
# 0      879         9.45  2012  Autódromo José Carlos Pace
# 17    1029         8.77  2019  Autódromo José Carlos Pace
# 20      35         8.76  2008  Autódromo José Carlos Pace
# 39    1071         8.34  2021  Autódromo José Carlos Pace
# 43      16         8.31  2009  Autódromo José Carlos Pace
# 47    1095         8.20  2022  Autódromo José Carlos Pace
# 51    1008         8.18  2018  Autódromo José Carlos Pace
# 65     967         7.94  2016  Autódromo José Carlos Pace
#
#                  NameOfCircuit  year  round  circuitId                  name  \
# 0   Autódromo José Carlos Pace  2012     20         18  Brazilian Grand Prix
# 17  Autódromo José Carlos Pace  2019     20         18  Brazilian Grand Prix
# 20  Autódromo José Carlos Pace  2008     18         18  Brazilian Grand Prix
# 39  Autódromo José Carlos Pace  2021     19         18  São Paulo Grand Prix
# ...

# %%
# Hypothesis 3 Do the amount of overtakings affect the score?
# Lets start by looking at the change in positions across a race by each driver
# As Brazil is one of the highest average rated circuit and on the top 100 8 times lets comapre a few races there.
# We will pick the top 3 highest rated races

# pair driverId to a name

laptimes_driverids = pd.merge(laptimes, drivers, on="driverId", how="left")
laptimes_driverids = laptimes_driverids.drop(['number', 'code', 'forename', 'surname', 'dob', 'nationality'], axis=1)
laptimes_driverids_879 = laptimes_driverids[laptimes_driverids['raceId'] == 879]

laptimes_driverids_1029 = laptimes_driverids[laptimes_driverids['raceId'] == 1029]

laptimes_driverids_35 = laptimes_driverids[laptimes_driverids['raceId'] == 35]


#laptimes_driverids.sort_values(by="Race Rating", ascending=False, inplace=True)

# %%
laptimes_driverids_879
# Out:
#        raceId  driverId  lap  position      time  milliseconds driverRef
# 47933     879         1    1         1  1:26.332         86332  hamilton
# 47934     879         1    2         1  1:21.858         81858  hamilton
# 47935     879         1    3         1  1:21.979         81979  hamilton
# 47936     879         1    4         1  1:22.868         82868  hamilton
# 47937     879         1    5         1  1:23.543         83543  hamilton
# ...       ...       ...  ...       ...       ...           ...       ...
# 49323     879        20   67         6  1:27.571         87571    vettel
# 49324     879        20   68         6  1:27.861         87861    vettel
# 49325     879        20   69         6  1:28.283         88283    vettel
# 49326     879        20   70         6  1:38.974         98974    vettel
# 49327     879        20   71         6  2:00.530        120530    vettel
#
# [1395 rows x 7 columns]

# %%
laptimes_driverids_1029
# Out:
#         raceId  driverId  lap  position      time  milliseconds driverRef
# 470048    1029       847   53        18  1:40.613        100613   russell
# 470049    1029       847   52        18  1:27.588         87588   russell
# 470050    1029       847   51        19  1:16.129         76129   russell
# 470051    1029       847   50        19  1:15.300         75300   russell
# 470052    1029       847   49        19  1:15.248         75248   russell
# ...        ...       ...  ...       ...       ...           ...       ...
# 471424    1029       847   67        14  1:50.428        110428   russell
# 471425    1029       847   68        14  1:38.854         98854   russell
# 471426    1029       847   69        14  2:07.480        127480   russell
# 471427    1029       847   70        13  1:17.011         77011   russell
# 471428    1029       847   71        13  1:14.320         74320   russell
#
# [1381 rows x 7 columns]

# %%
laptimes_driverids_35
# Out:
#         raceId  driverId  lap  position      time  milliseconds   driverRef
# 341615      35         8    1         3  1:44.672        104672   raikkonen
# 341616      35         8    2         3  2:10.763        130763   raikkonen
# 341617      35         8    3         3  2:01.605        121605   raikkonen
# 341618      35         8    4         3  1:59.134        119134   raikkonen
# 341619      35         8    5         3  1:20.310         80310   raikkonen
# ...        ...       ...  ...       ...       ...           ...         ...
# 342876      35         5   67         8  1:19.957         79957  kovalainen
# 342877      35         5   68         8  1:20.485         80485  kovalainen
# 342878      35         5   69         8  1:22.687         82687  kovalainen
# 342879      35         5   70         8  1:24.917         84917  kovalainen
# 342880      35         5   71         7  1:24.945         84945  kovalainen
#
# [1266 rows x 7 columns]

# %%
# Display all three races and their change in positions by each driver each lap

# laptimes_driverids_879

laptimes_driverids_879_grouped = laptimes_driverids_879.groupby('driverRef')
fig = plt.figure(figsize=(14,8))
for driverRef, group in laptimes_driverids_879_grouped:
    plt.plot(group['lap'], group['position'], label=f'{driverRef}')

plt.xlabel('Lap Number')
plt.ylabel('Position at Specific Lap')
plt.title('Line Graph Showing Position Change Each Lap by Each Driver (Brazilian Grand Prix, 2012)')
plt.legend(title= "Driver", bbox_to_anchor=(1.01, 1), loc='upper left')
plt.gca().invert_yaxis() #inverts y axis
plt.show()


# laptimes_driverids_1029

fig = plt.figure(figsize=(14,8))
laptimes_driverids_1029_grouped = laptimes_driverids_1029.groupby('driverRef')
fig = plt.figure(figsize=(14,8))
for driverRef, group in laptimes_driverids_1029_grouped:
    plt.plot(group['lap'], group['position'], label=f'{driverRef}')

plt.xlabel('Lap Number')
plt.ylabel('Position at Specific Lap')
plt.title('Line Graph Showing Position Change Each Lap by Each Driver (Brazilian Grand Prix, 2019)')
plt.legend(title= "Driver", bbox_to_anchor=(1.01, 1), loc='upper left')
plt.gca().invert_yaxis() #inverts y axis
plt.show()


# laptimes_driverids_35

fig = plt.figure(figsize=(14,8))
laptimes_driverids_35_grouped = laptimes_driverids_35.groupby('driverRef')
fig = plt.figure(figsize=(14,8))
for driverRef, group in laptimes_driverids_35_grouped:
    plt.plot(group['lap'], group['position'], label=f'{driverRef}')

plt.xlabel('Lap Number')
plt.ylabel('Position at Specific Lap')
plt.title('Line Graph Showing Position Change Each Lap by Each Driver (Brazilian Grand Prix, 2008)')
plt.legend(title= "Driver", bbox_to_anchor=(1.01, 1), loc='upper left')
plt.gca().invert_yaxis() #inverts y axis
plt.show()

# %%
# Now lets comapre these to the worst rated Brazilian Grand Prix
# raceId = 967

laptimes_driverids_967 = laptimes_driverids[laptimes_driverids['raceId'] == 967]

laptimes_driverids_967_grouped = laptimes_driverids_967.groupby('driverRef')
fig = plt.figure(figsize=(14,8))
for driverRef, group in laptimes_driverids_967_grouped:
    plt.plot(group['lap'], group['position'], label=f'{driverRef}')

plt.xlabel('Lap Number')
plt.ylabel('Position at Specific Lap')
plt.title('Line Graph Showing Position Change Each Lap by Each Driver (Brazilian Grand Prix, 2016)')
plt.legend(title= "Driver", bbox_to_anchor=(1.01, 1), loc='upper left')
plt.gca().invert_yaxis() #inverts y axis
plt.show()

# %%
# Now lets comapre these to the worst rated Grand Prix in this dataset
# Not using spa 2021 as no race happened
# raceId = 1017

laptimes_driverids_1017 = laptimes_driverids[laptimes_driverids['raceId'] ==1017]

laptimes_driverids_1017_grouped = laptimes_driverids_1017.groupby('driverRef')
fig = plt.figure(figsize=(14,8))
for driverRef, group in laptimes_driverids_1017_grouped:
    plt.plot(group['lap'], group['position'], label=f'{driverRef}')

plt.xlabel('Lap Number')
plt.ylabel('Position at Specific Lap')
plt.title('Line Graph Showing Position Change Each Lap by Each Driver (French Grand Prix, 2019)')
plt.legend(title= "Driver", bbox_to_anchor=(1.01, 1), loc='upper left')
plt.gca().invert_yaxis() #inverts y axis
plt.show()

# %%
# Now lets count the number of overtakes and comapre that to Race Rating
# overtaking_count function

# There are a few things to be careful with in this function
# For something to count as an "overtake", a driver changes their position between two consecutive laps. This would mean an "overtake" has occured.
# Count this number then divide by 2 will give the number of overtakes as one overtake includes one driver gaining a position and the other losing a position.

def overtaking_count(laptimes, race_id):
    drivers = []
    for driver in laptimes[laptimes.raceId == race_id].driverId:
        if driver not in drivers:
            drivers.append(driver)
    
    prev_pos = 0
    overtakes = 0
    for driver in drivers:
        for lapPos in laptimes[(laptimes.raceId == race_id) & (laptimes.driverId == driver)].position:
            if lapPos != prev_pos:
                prev_pos = lapPos
                overtakes = overtakes + 1
                overtakings = overtakes/2
                
    return int(overtakings)

# %%
# new df with overtakes column

race_stats_ratings_no_spa_2021['overtakes'] = race_stats_ratings_no_spa_2021.raceId.apply(lambda x: overtaking_count(laptimes, x))
#race_stats_ratings_no_spa_2021.sort_values(by="overtakes", ascending=False)
# Out:
# C:\Users\jaceh\AppData\Local\Temp\ipykernel_17112\1838499974.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   race_stats_ratings_no_spa_2021['overtakes'] = race_stats_ratings_no_spa_2021.raceId.apply(lambda x: overtaking_count(laptimes, x))

# %%
#Scatter plot Number of Overtakes against Race Rating

x = race_stats_ratings_no_spa_2021["Race Rating"]
y = race_stats_ratings_no_spa_2021["overtakes"]
b = coef_linear_regression(x, y)

plt.figure(figsize=(14, 8))

# Calculate correlation coefficient
corr_coef_value_overtakes = correlation_coefficient(x, y)

# Create the title with proper formatting
title_text = (
    f"Scatter Plot Showing Number of Overtakes against Race Rating\n"
    f"y = mx + c where m = {round(b[1], 2)} and c = {round(b[0], 2)}\n"
    f"Pearson Correlation Coefficient: {round(corr_coef_value_overtakes, 2)}"
)

plt.title(title_text)
plt.xlabel("Race Rating")
plt.ylabel("Number of Overtakes in a Race")
plot_regression_line(x, y, b)
plt.show()
